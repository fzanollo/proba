# %% [markdown]
# ![image.png](attachment:image.png)

# %%
1 - pexp(6.4, rate=1/3.4)
# Out:
# [1] 0.1522315

# %% [markdown]
# <img src="attachment:image.png" width="700">

# %%
for(n in c(10,50)){
    data = read.csv(sprintf("datos_id93411_n_%d.csv0.95.csv", n))
    
    alpha = 0.95
    mu = 3.4
    dobleSuma = 2*sum(data)
    
    limInf = qchisq(1-alpha/2, df=2*n) / dobleSuma
    limSup = qchisq(alpha/2, df=2*n) / dobleSuma
    
    cat("para cantidad ", n, "\n")
    cat("[", limInf, ",", limSup, "]\n\n")
}
# Out:
# para cantidad  10
# [ 1.760973 , 1.691558 ]
#
# para cantidad  50
# [ 2.397128 , 2.354871 ]
